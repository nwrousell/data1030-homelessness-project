# %% [markdown]
# ## Exploratory Data Analysis
#
# This notebook contains the EDA for the dataset: looking at missing values, visualizations, etc.
#
# This is the [dataset](https://www.huduser.gov/portal/datasets/hpmd.html). Here is the [paper](https://www.huduser.gov/portal/sites/default/files/pdf/Market-Predictors-of-Homelessness.pdf) it was created for.

# %% [markdown]
# **Import packages and read in the dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
sns.set()
# style.use("fivethirtyeight")

df = pd.read_csv("../data/original_dataset.csv")
print(df.shape)
df
# Out:
# (3008, 332)
#       year cocnumber  pit_tot_shelt_pit_hud  pit_tot_unshelt_pit_hud  \
# 0     2010    AK-500                 1113.0                    118.0
# 1     2011    AK-500                 1082.0                    141.0
# 2     2012    AK-500                 1097.0                     50.0
# 3     2013    AK-500                 1070.0                     52.0
# 4     2014    AK-500                  970.0                     53.0
# ...    ...       ...                    ...                      ...
# 3003  2013    WY-500                  501.0                    452.0
# 3004  2014    WY-500                  563.0                    194.0
# 3005  2015    WY-500                  507.0                    291.0
# 3006  2016    WY-500                  491.0                    366.0
# 3007  2017    WY-500                  510.0                    363.0
#
#       pit_tot_hless_pit_hud  pit_ind_shelt_pit_hud  pit_ind_unshelt_pit_hud  \
# 0                    1231.0                  633.0                    107.0
# 1                    1223.0                  677.0                    117.0
# 2                    1147.0                  756.0                     35.0
# 3                    1122.0                  792.0                     52.0
# 4                    1023.0                  688.0                     48.0
# ...                     ...                    ...                      ...
# 3003                  953.0                  306.0                    371.0
# 3004                  757.0                  327.0                    136.0
# 3005                  798.0                  292.0                    208.0
# 3006                  857.0                  277.0                    240.0
# 3007                  873.0                  383.0                    239.0
#
#       pit_ind_hless_pit_hud  pit_perfam_shelt_pit_hud  \
# 0                     740.0                     480.0
# 1                     794.0                     405.0
# 2                     791.0                     341.0
# 3                     844.0                     278.0
# 4                     736.0                     282.0
# ...                     ...                       ...
# 3003                  677.0                     195.0
# 3004                  463.0                     236.0
# 3005                  500.0                     215.0
# 3006                  517.0                     214.0
# 3007                  622.0                     127.0
#
#       pit_perfam_unshelt_pit_hud  ...  sub_high_cost_rent75  \
# 0                           11.0  ...                     1
# 1                           24.0  ...                     1
# 2                           15.0  ...                     1
# 3                            0.0  ...                     1
# 4                            5.0  ...                     1
# ...                          ...  ...                   ...
# 3003                        81.0  ...                     0
# 3004                        58.0  ...                     1
# 3005                        83.0  ...                     0
# 3006                       126.0  ...                     1
# 3007                       124.0  ...                     0
#
#       sub_high_cost_homeval75  sub_high_rent_share75  \
# 0                           1                      1
# 1                           1                      0
# 2                           1                      1
# 3                           1                      0
# 4                           1                      1
# ...                       ...                    ...
# 3003                        0                      0
# 3004                        1                      1
# 3005                        0                      0
# 3006                        1                      1
# 3007                        0                      0
#
#       tight_high_cost_rental_mkt  sub_tight_high_cost_rent  \
# 0                              3                         1
# 1                              3                         1
# 2                              3                         1
# 3                              3                         1
# 4                              3                         1
# ...                          ...                       ...
# 3003                           0                         0
# 3004                           3                         1
# 3005                           0                         0
# 3006                           3                         1
# 3007                           0                         0
#
#       sub_west_coast_all_urb  sub_west_census  major_city  suburban  rural
# 0                          1                1           1         0      0
# 1                          1                1           1         0      0
# 2                          1                1           1         0      0
# 3                          1                1           1         0      0
# 4                          1                1           1         0      0
# ...                      ...              ...         ...       ...    ...
# 3003                       0                1           0         0      1
# 3004                       0                1           0         0      1
# 3005                       0                1           0         0      1
# 3006                       0                1           0         0      1
# 3007                       0                1           0         0      1
#
# [3008 rows x 332 columns]

# %% [markdown]
# **Look at missing values**

# %%
perc_missing_per_ftr = df.isnull().sum(axis=0)/df.shape[0]
print('fraction of missing values in features:')
print(perc_missing_per_ftr.to_string())
# print('data types of the features with missing values:')
# # print(df[perc_missing_per_ftr[perc_missing_per_ftr > 0].index].dtypes.to_string())
frac_missing = sum(df.isnull().sum(axis=1)!=0)/df.shape[0]
print('fraction of points with missing values:',frac_missing)
print('# of features with missing values:', sum(perc_missing_per_ftr > 0))
# Out:
# fraction of missing values in features:
# year                                0.000000
# cocnumber                           0.000000
# pit_tot_shelt_pit_hud               0.004654
# pit_tot_unshelt_pit_hud             0.004654
# pit_tot_hless_pit_hud               0.004654
# pit_ind_shelt_pit_hud               0.004654
# pit_ind_unshelt_pit_hud             0.004654
# pit_ind_hless_pit_hud               0.004654
# pit_perfam_shelt_pit_hud            0.004654
# pit_perfam_unshelt_pit_hud          0.004654
# pit_perfam_hless_pit_hud            0.004654
# pit_ind_chronic_hless_pit_hud       0.004654
# pit_perfam_chronic_hless_pit_hud    0.377992
# pit_vet_hless_pit_hud               0.128657
# econ_urb_urbanicity                 0.000000
# coctag                              0.000000
# panelvar                            0.000000
# hou_pol_totalind_hud                0.750997
# hou_pol_totalday_hud                0.750997
# hou_pol_totalexit_hud               0.750997
# hou_pol_numret6mos_hud              0.750997
# hou_pol_numret12mos_hud             0.750997
# hou_pol_fedfundcoc                  0.000000
# hou_pol_fund_project                0.016622
# hou_pol_bed_es_hic_hud              0.005319
# hou_pol_bed_oph_hic_hud             0.005319
# hou_pol_bed_psh_hic_hud             0.005319
# hou_pol_bed_rrh_hic_hud             0.005319
# hou_pol_bed_sh_hic_hud              0.005319
# hou_pol_bed_th_hic_hud              0.005319
# hou_pol_perm_bed_hic_hud            0.005319
# hou_pol_temp_bed_hic_hud            0.005319
# dem_pop_pop_census                  0.000000
# dem_pop_male_census                 0.000000
# dem_pop_female_census               0.000000
# dem_pop_child_census                0.000000
# dem_pop_adult_census                0.000000
# dem_pop_senior_census               0.000000
# dem_soc_white_census                0.000000
# dem_soc_black_census                0.000000
# dem_soc_native_census               0.000000
# dem_soc_asian_census                0.000000
# dem_soc_pacific_census              0.000000
# dem_soc_racetwo_census              0.000000
# dem_soc_hispanic_census             0.000000
# dem_age_boom_census                 0.875000
# total_rent_inventory_acs5yr         0.750000
# dem_soc_ed_bach_acs5yr              0.750000
# dem_soc_ed_hsgrad_acs5yr            0.750000
# dem_soc_ed_lesshs_acs5yr            0.750000
# dem_soc_ed_somecoll_acs5yr          0.750000
# dem_soc_vet_acs5yr                  0.750000
# dem_soc_singparent_acs5yr           0.750000
# dem_health_ins_acs5yr               0.875000
# econ_labor_topskilled_acs5yr        0.750000
# econ_labor_midskilled_acs5yr        0.750000
# econ_labor_unskilled_acs5yr         0.750000
# econ_labor_incineq_acs5yr           0.750000
# econ_labor_medinc_acs5yr            0.750000
# econ_labor_pov_acs5yr               0.750000
# dem_soc_singadult_acs5yr            0.750000
# econ_sn_cashasst_acs5yr             0.750000
# hou_mkt_homeval_acs5yr              0.750000
# hou_mkt_homeage_acs5yr              0.750000
# hou_mkt_homeage1940_acs5yr          0.750000
# hou_mkt_medrent_acs5yr              0.750000
# hou_mkt_medrentgross_acs5yr         0.750000
# hou_mkt_ovrcrowd_acs5yr             0.750000
# hou_mkt_rentshare_acs5yr            0.750000
# hou_mkt_rentvacancy_acs5yr          0.750000
# hou_mkt_utility_acs5yr              0.750000
# hou_mkt_burden_own_acs5yr           0.750000
# hou_mkt_burden_sev_own_acs5yr       0.750000
# hou_mkt_burden_rent_acs5yr          0.750000
# hou_mkt_burden_sev_rent_acs5yr      0.750000
# fhfa_hpi_flag                       0.000000
# fhfa_hpi_2009                       0.000000
# econ_labor_force_pop_BLS            0.000000
# econ_labor_emp_pop_BLS              0.000000
# econ_labor_unemp_pop_BLS            0.000000
# econ_labor_unemp_rate_BLS           0.000000
# hou_mkt_area_census                 0.000000
# dem_pop_density_census              0.000000
# hou_mkt_density_census              0.000000
# dem_pop_mig_census                  0.000000
# hou_pol_hudunit_psh_hud             0.000000
# hou_pol_occhudunit_psh_hud          0.000000
# hou_mkt_pplunit_psh_hud             0.001330
# hou_pol_eli_psh_hud                 0.001330
# hou_mkt_pctoverhouse_psh_hud        0.001330
# hou_mkt_units_census                0.000000
# hou_mkt_pmt_totbldg_census          0.000000
# hou_mkt_pmt_totunit_census          0.000000
# hou_mkt_pmt_totvalue_census         0.000000
# econ_labor_pov_pop_census           0.000000
# econ_labor_medinc_census            0.000000
# econ_sn_ssdi_SSA                    0.000000
# econ_sn_ssdi_part_rate_SSA          0.000000
# econ_sn_ssi_part_SSA                0.000000
# econ_sn_ssi_pay_SSA                 0.000000
# econ_sn_ssi_part_rate_SSA           0.000000
# hou_mkt_evict_count                 0.000000
# hou_mkt_evict_file_count            0.000000
# hou_mkt_renter_count_evlab          0.000000
# hou_mkt_evict_flag                  0.000000
# hou_mkt_evict_file_rate             0.000000
# hou_mkt_evict_rate                  0.000000
# dem_health_alcoholdeath_IMHE        0.875000
# dem_mort_lifeexp_IMHE               0.875000
# econ_sn_eitc_irs                    0.125000
# econ_sn_returns_irs                 0.125000
# econ_sn_eitc_irs_share              0.125000
# dem_health_mentalhlth_chr           0.875000
# dem_health_excesdrink_chr           0.875000
# dem_health_cost_dart                0.000000
# hou_pol_hlessconduct_food           0.000000
# hou_pol_hlessconduct_total          0.000000
# hou_pol_hlessconduct_sleep          0.000000
# hou_pol_hlessconduct_loiter         0.000000
# hou_pol_hlessconduct_beg            0.000000
# env_wea_avgtemp_summer_noaa         0.000665
# env_wea_precip_annual_noaa          0.000000
# cpi_2017                            0.000000
# env_wea_avgtemp_noaa                0.000000
# env_wea_precip_noaa                 0.000000
# state_abr                           0.000000
# pit_miss                            0.000000
# odd_flag                            0.000000
# pit_hless_balance                   0.000000
# pit_shelt_balance                   0.000000
# pit_unshelt_balance                 0.000000
# unbalance_flag                      0.000000
# pit_shelt_pit_hud_share             0.004654
# pit_unshelt_pit_hud_share           0.004654
# pit_hless_pit_hud_share             0.004654
# missing                             0.000000
# dem_pop_adult_census_share          0.000000
# dem_pop_child_census_share          0.000000
# dem_pop_female_census_share         0.000000
# dem_pop_male_census_share           0.000000
# dem_pop_mig_census_share            0.000000
# dem_pop_senior_census_share         0.000000
# dem_age_boom_census_2011            0.000000
# dem_soc_asian_census_share          0.000000
# dem_soc_black_census_share          0.000000
# dem_soc_hispanic_census_share       0.000000
# dem_soc_native_census_share         0.000000
# dem_soc_pacific_census_share        0.000000
# dem_soc_racetwo_census_share        0.000000
# dem_soc_white_census_share          0.000000
# dem_soc_other_census_share          0.000000
# dem_health_mentalhlth_chr_share     0.875000
# dem_health_mhlth_chr_share_2017     0.000000
# dem_health_excesdrink_chr_2017      0.000000
# dem_health_alcdeath_IMHE_2015       0.000000
# dem_mort_lifeexp_IMHE_2015          0.000000
# dem_health_ins_acs5yr_2012          1.000000
# dem_health_ins_acs5yr_2017          0.000000
# dem_soc_ed_bach_acs5yr_2012         0.000000
# dem_soc_ed_bach_acs5yr_2017         0.000000
# dem_soc_ed_bach_acs5yr_diff         0.000000
# dem_soc_ed_somecoll_acs5yr_2012     0.000000
# dem_soc_ed_somecoll_acs5yr_2017     0.000000
# dem_soc_ed_hsgrad_acs5yr_2012       0.000000
# dem_soc_ed_hsgrad_acs5yr_2017       0.000000
# dem_soc_ed_lesshs_acs5yr_2012       0.000000
# dem_soc_ed_lesshs_acs5yr_2017       0.000000
# dem_soc_ed_lesshs_acs5yr_diff       0.000000
# dem_soc_singparent_acs5yr_2012      0.000000
# dem_soc_singparent_acs5yr_2017      0.000000
# dem_soc_singparent_acs5yr_diff      0.000000
# dem_soc_singadult_acs5yr_2012       0.000000
# dem_soc_singadult_acs5yr_2017       0.000000
# dem_soc_singadult_acs5yr_diff       0.000000
# dem_soc_vet_acs5yr_2012             0.000000
# dem_soc_vet_acs5yr_2017             0.000000
# dem_soc_vet_acs5yr_diff             0.000000
# econ_labor_incineq_acs5yr_2012      0.000000
# econ_labor_incineq_acs5yr_2017      0.000000
# econ_labor_incineq_acs5yr_diff      0.000000
# econ_labor_topskill_acs5yr_2012     0.000000
# econ_labor_topskill_acs5yr_2017     0.000000
# econ_labor_topskill_acs5yr_diff     0.000000
# econ_labor_midskill_acs5yr_2012     0.000000
# econ_labor_midskill_acs5yr_2017     0.000000
# econ_labor_midskill_acs5yr_diff     0.000000
# econ_labor_unskill_acs5yr_2012      0.000000
# econ_labor_unskill_acs5yr_2017      0.000000
# econ_labor_unskill_acs5yr_diff      0.000000
# econ_labor_medinc_acs5yr_2012       0.000000
# econ_labor_medinc_acs5yr_2017       0.000000
# econ_labor_pov_pop_census_share     0.000000
# econ_sn_cashasst_acs5yr_2012        0.000000
# econ_sn_cashasst_acs5yr_2017        0.000000
# econ_sn_cashasst_acs5yr_diff        0.000000
# hou_mkt_rentshare_acs5yr_2012       0.000000
# hou_mkt_rentshare_acs5yr_2017       0.000000
# hou_mkt_rentshare_acs5yr_diff       0.000000
# hou_mkt_rentvacancy_acs5yr_2012     0.000000
# hou_mkt_rentvacancy_acs5yr_2017     0.000000
# hou_mkt_rentvacancy_acs5yr_diff     0.000000
# hou_mkt_ovrcrowd_acs5yr_2012        0.000000
# hou_mkt_ovrcrowd_acs5yr_2017        0.000000
# hou_mkt_ovrcrowd_acs5yr_diff        0.000000
# hou_mkt_homeage_acs5yr_2012         0.000000
# hou_mkt_homeage_acs5yr_2017         0.000000
# hou_mkt_homeage_acs5yr_diff         0.000000
# hou_mkt_homeage1940_acs5yr_2012     0.000000
# hou_mkt_homeage1940_acs5yr_2017     0.000000
# hou_mkt_homeage1940_acs5yr_diff     0.000000
# hou_mkt_homeval_acs5yr_2012         0.000000
# hou_mkt_homeval_acs5yr_2017         0.000000
# hou_mkt_homeval_acs5yr_diff         0.000000
# hou_mkt_medrent_acs5yr_2012         0.000000
# hou_mkt_medrent_acs5yr_2017         0.000000
# hou_mkt_medrent_acs5yr_diff         0.000000
# hou_mkt_utility_acs5yr_2012         0.000000
# hou_mkt_utility_acs5yr_2017         0.000000
# hou_mkt_utility_acs5yr_diff         0.000000
# hou_mkt_burden_own_acs5yr_2012      0.000000
# hou_mkt_burden_own_acs5yr_2017      0.000000
# hou_mkt_burden_own_acs5yr_diff      0.000000
# hou_mkt_burden_sev_own_acs_2012     0.000000
# hou_mkt_burden_sev_own_acs_2017     0.000000
# hou_mkt_burden_sev_own_acs_diff     0.000000
# hou_mkt_burden_rent_acs5yr_2012     0.000000
# hou_mkt_burden_rent_acs5yr_2017     0.000000
# hou_mkt_burden_rent_acs5yr_diff     0.000000
# hou_mkt_burden_sev_rent_acs_2012    0.000000
# hou_mkt_burden_sev_rent_acs_2017    0.000000
# hou_mkt_burden_sev_rent_acs_diff    0.000000
# hou_pol_hudunit_psh_hud_share       0.000000
# hou_mkt_pmt_unit_census_share       0.000000
# urban_cat                           0.000000
# state                               0.000000
# evict_file_flag                     0.000000
# evict_flag                          0.000000
# fedfundcoc_flag                     0.000000
# hou_mkt_density_dummy               0.000000
# hou_mkt_homeval_xt                  0.500000
# hou_mkt_burden_own_xt               0.500000
# hou_mkt_burden_sev_own_xt           0.500000
# hou_mkt_burden_rent_xt              0.500000
# hou_mkt_burden_sev_rent_xt          0.500000
# hou_mkt_homeage_xt                  0.500000
# hou_mkt_homeage1940_xt              0.500000
# hou_mkt_medrent_xt                  0.500000
# hou_mkt_utility_xt                  0.500000
# hou_mkt_rentshare_xt                0.500000
# hou_mkt_rentvacancy_xt              0.500000
# hou_mkt_ovrcrowd_xt                 0.500000
# econ_labor_midskill_xt              0.500000
# econ_labor_incineq_xt               0.500000
# econ_sn_cashasst_xt                 0.500000
# dem_soc_ed_bach_xt                  0.500000
# dem_soc_ed_somecoll_xt              0.500000
# dem_soc_ed_hsgrad_xt                0.500000
# dem_soc_ed_lesshs_xt                0.500000
# dem_health_ins_xt                   0.750000
# dem_soc_singadult_xt                0.500000
# dem_soc_singparent_xt               0.500000
# dem_soc_vet_xt                      0.500000
# ln_hou_mkt_homeval_xt               0.500000
# ln_hou_mkt_medrent_xt               0.500000
# ln_econ_labor_medinc_census         0.000000
# flag_d_hless                        0.000000
# flag_xt_hless                       0.000000
# flag_d_shelt                        0.000000
# flag_xt_shelt                       0.000000
# flag_d_unshelt                      0.000000
# flag_xt_unshelt                     0.000000
# d_pit_hless_pit_hud_share           0.875997
# d_pit_shelt_pit_hud_share           0.875997
# d_pit_unshelt_pit_hud_share         0.875997
# d_hou_mkt_homeval_xt                0.875000
# d_hou_mkt_burden_sev_rent_xt        0.875000
# d_hou_mkt_burden_own_xt             0.875000
# d_hou_mkt_burden_sev_own_xt         0.875000
# d_hou_mkt_burden_rent_xt            0.875000
# d_hou_mkt_medrent_xt                0.875000
# d_hou_mkt_utility_xt                0.875000
# d_fhfa_hpi_2009                     0.875000
# d_hou_mkt_homeage1940_xt            0.875000
# d_hou_mkt_rentshare_xt              0.875000
# d_hou_mkt_rentvacancy_xt            0.875000
# d_hou_mkt_ovrcrowd_xt               0.875000
# d_hou_mkt_pctoverhouse_psh_hud      0.875000
# d_hou_mkt_evict_rate                0.875000
# d_hou_pol_eli_psh_hud               0.875000
# d_hou_pol_hudunit_psh_hud_share     0.875000
# d_hou_pol_occhudunit_psh_hud        0.875000
# d_hou_pol_fedfundcoc                0.875000
# d_econ_labor_medinc_census          0.875000
# d_econ_labor_unemp_rate_BLS         0.875000
# d_econ_labor_incineq_xt             0.875000
# d_econ_sn_cashasst_xt               0.875000
# d_econ_sn_eitc_irs_share            0.875000
# d_econ_sn_ssdi_part_rate_SSA        0.875000
# d_econ_sn_ssi_part_rate_SSA         0.875000
# d_dem_soc_white_census_share        0.875000
# d_dem_soc_black_census_share        0.875000
# d_dem_soc_hispanic_census_share     0.875000
# d_dem_soc_asian_census_share        0.875000
# d_dem_pop_child_census_share        0.875000
# d_dem_pop_adult_census_share        0.875000
# d_dem_pop_senior_census_share       0.875000
# d_dem_pop_female_census_share       0.875000
# d_dem_pop_mig_census_share          0.875000
# d_dem_soc_ed_bach_xt                0.875000
# d_dem_health_cost_dart              0.875000
# d_dem_soc_singadult_xt              0.875000
# d_dem_soc_singparent_xt             0.875000
# d_dem_soc_vet_xt                    0.875000
# d_env_wea_avgtemp_noaa              0.875000
# d_env_wea_avgtemp_summer_noaa       0.875000
# d_env_wea_precip_noaa               0.875000
# d_env_wea_precip_annual_noaa        0.875000
# dem_soc_ed_lessbach_xt              0.500000
# census_region                       0.000000
# census_division                     0.000000
# sub_west_coast                      0.000000
# sub_low_rent_vacancy                0.000000
# sub_high_cost_rent75                0.000000
# sub_high_cost_homeval75             0.000000
# sub_high_rent_share75               0.000000
# tight_high_cost_rental_mkt          0.000000
# sub_tight_high_cost_rent            0.000000
# sub_west_coast_all_urb              0.000000
# sub_west_census                     0.000000
# major_city                          0.000000
# suburban                            0.000000
# rural                               0.000000
# fraction of points with missing values: 1.0
# # of features with missing values: 144

# %% [markdown]
# ### Feature Engineering

# %%
df["shelt_per_10k"] = (df["pit_tot_shelt_pit_hud"] / df["dem_pop_pop_census"]) * 10000
df["unshelt_per_10k"] = (df["pit_tot_unshelt_pit_hud"] / df["dem_pop_pop_census"]) * 10000
df["all_per_10k"] = (df["pit_tot_hless_pit_hud"] / df["dem_pop_pop_census"]) * 10000
df["urbanicity"] = np.where(df["major_city"] == 1, 2, np.where(df["suburban"] == 1, 1,0))

# save df with new features
df.to_csv("../data/dataset_ftr_eng.csv", index=False)

# %% [markdown]
# ## Dataset Exploration (years, states, general counts)

# %%
#df = df.drop(["dem_health_ins_acs5yr_2012"], axis=1) # every value is missing

print("Years represented:", np.unique(df["year"], return_counts=True))
states = np.unique(df["cocnumber"].str[:2])
print("\nStates:", states)

print("\nTotal Sheltered:\n", df["pit_tot_shelt_pit_hud"].describe())
print("\nTotal Unsheltered:\n", df["pit_tot_unshelt_pit_hud"].describe())
# Out:
# Years represented: (array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype=int64), array([376, 376, 376, 376, 376, 376, 376, 376], dtype=int64))
#
# States: ['AK' 'AL' 'AR' 'AZ' 'CA' 'CO' 'CT' 'DC' 'DE' 'FL' 'GA' 'HI' 'IA' 'ID'
#  'IL' 'IN' 'KS' 'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC'
#  'ND' 'NE' 'NH' 'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'RI' 'SC' 'SD'
#  'TN' 'TX' 'UT' 'VA' 'VT' 'WA' 'WI' 'WV' 'WY']
#
# Total Sheltered:
#  count     2994.000000
# mean      1033.852037
# std       3445.807044
# min          3.000000
# 25%        224.000000
# 50%        445.500000
# 75%        961.500000
# max      72565.000000
# Name: pit_tot_shelt_pit_hud, dtype: float64
#
# Total Unsheltered:
#  count     2994.000000
# mean       526.581830
# std       1742.313472
# min          0.000000
# 25%         36.250000
# 50%        114.000000
# 75%        418.250000
# max      42828.000000
# Name: pit_tot_unshelt_pit_hud, dtype: float64

# %%
print("# of CoCs with 10,000+ sheltered homeless:",sum(df["pit_tot_shelt_pit_hud"] > 10000))

plot_df = df.copy(deep=True)
plot_df[plot_df["pit_tot_unshelt_pit_hud"] == 0] = np.NaN
sns.histplot(data=plot_df, x="pit_tot_unshelt_pit_hud", log_scale=True, label="Unsheltered", kde=True)
sns.histplot(data=plot_df, x="pit_tot_shelt_pit_hud", log_scale=True, label="Sheltered", kde=True)
plt.title("Homeless Count Distribution")
plt.legend()
plt.ylabel("Frequency")
plt.xlabel("Number of Homeless Recorded")
plt.savefig("../figures/homeless-count-distribution.png", dpi=500)
plt.show()
# Out:
# # of CoCs with 10,000+ sheltered homeless: 21

# %%
# stacked histogram with sheltered/unsheltered homeless per year
total_counts_per_year = df.loc[:,["pit_tot_shelt_pit_hud","pit_tot_unshelt_pit_hud","year"]].groupby(["year"]).sum()
total_counts_per_year.loc[:,["pit_tot_shelt_pit_hud","pit_tot_unshelt_pit_hud"]] /= 1000
fig, ax = plt.subplots(figsize=(10,5))
total_counts_per_year.plot(ax=ax, kind='bar', stacked=True, legend=False)
plt.legend(loc='upper right', labels=['Sheltered', 'Unsheltered'])
plt.title("Sheltered/Unsheltered homeless counts over time")
plt.ylabel("Count of homeless (thousands)")
plt.xlabel("Year")
plt.savefig("../figures/homeless_counts_by_year.png", dpi=500)
plt.show()

# %%
per_year = df.loc[:,["shelt_per_10k","unshelt_per_10k","year"]].groupby(["year"], as_index=False).mean()
sns.lineplot(data=per_year,x="year", y="shelt_per_10k", label="Sheltered")
sns.lineplot(data=per_year,x="year", y="unshelt_per_10k", label="Unsheltered")
plt.title("Homeless rate over time")
plt.ylabel("Homeless per 10,000 individuals")
plt.savefig("../figures/homeless_rate_over_time.png", dpi=500)
plt.show()

# %%
import matplotlib.patches as mpatches
# rural vs. urban rates over time
ratio_by_urbanicity = df.loc[:,["shelt_per_10k", "unshelt_per_10k", "urbanicity", "year"]].groupby(["year", "urbanicity"], as_index=False).mean()
ratio_by_urbanicity = pd.melt(ratio_by_urbanicity, ["year","urbanicity"])
ratio_by_urbanicity["variable"] = ratio_by_urbanicity["variable"] + "-" + ratio_by_urbanicity["urbanicity"].astype(str)
ratio_by_urbanicity.drop(["urbanicity"], axis=1)
ax = sns.lineplot(data=ratio_by_urbanicity, x="year", y="value", hue="variable", marker="o")
legend_handles, _= ax.get_legend_handles_labels()
plt.legend(handles=legend_handles,labels=['Sheltered-Rural', 'Sheltered-Suburban', 'Sheltered-Urban', 'Unsheltered-Rural', 'Unsheltered-Suburban', 'Unsheltered-Urban'])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title("Homeless rates in differerent urbanicities")
plt.ylabel("Homeless per 10,000 individuals")
plt.xlabel("Year")
caption = """Homeless rates generally declined from 2010 to 2017. Urban rates are higher than the rest"""
plt.figtext(0.5, -0.15, caption, fontsize=11, horizontalalignment="center")
fig.savefig("../figures/homeless_rates_over_time_by_urbanicity.png") 
plt.show()

# %%
CoCs = df["cocnumber"].unique()
year_2010 = df[df["year"] == 2010].all_per_10k.to_numpy()
year_2017 = df[df["year"] == 2017].all_per_10k.to_numpy()
percent_change = ((year_2017 - year_2010) / year_2010) * 100
urbanicities = df.drop_duplicates(subset=["cocnumber"]).urbanicity
graph_df = pd.DataFrame({"CoC": CoCs, "percent_change": percent_change, "urbanicity": urbanicities})

fig, ax = plt.subplots()
sns.barplot(data=graph_df, x="urbanicity", y="percent_change", errorbar=None)
plt.ylabel("Average percent change from 2010 to 2017 (%)")
plt.title("Average Homeless Rate Change in Differing Urbanicities from 2010 to 2017")
plt.xlabel("Urbanicity")
ax.set_xticklabels(["Rural", "Suburban", "Urban"])
caption = """Homeless rates declined on average from 2010 to 2017 in all urbanicities, 
but much more in Urban and Suburban communities, with Rural communities 
lagging behind with only a 7% decrease in rates"""

plt.figtext(0.5, -0.15, caption, fontsize=11, horizontalalignment="center")
plt.savefig("../figures/avg_homeless_rate_change_in_differing_urbanicities.png",dpi=500)
plt.show()

# %% [markdown]
# ### Homeless Rates by state
# This [tutorial](https://medium.com/@alex_44314/use-python-geopandas-to-make-a-us-map-with-alaska-and-hawaii-39a9f5c222c6) was very helpful.

# %%
import geopandas as gpd
import matplotlib.colors as mcolors
from shapely.geometry import Polygon
from matplotlib.ticker import FuncFormatter

df["state"] = df["cocnumber"].str[:2]

state_rates = df.loc[:,["state", "all_per_10k"]].groupby("state").mean()
gdf = gpd.read_file('../data/us_states')
gdf = gdf.merge(state_rates,left_on='STUSPS',right_on='state')

variable = 'all_per_10k'

def makeColorColumn(gdf,variable,vmin,vmax):
    # apply a function to a column to create a new column of assigned colors & return full frame
    norm = mcolors.Normalize(vmin=vmin, vmax=vmax, clip=True)
    mapper = plt.cm.ScalarMappable(norm=norm, cmap=plt.cm.YlOrBr)
    gdf['value_determined_color'] = gdf[variable].apply(lambda x: mcolors.to_hex(mapper.to_rgba(x)))
    return gdf

# set the range for the choropleth values with the upper bound the rounded up maximum value
vmin, vmax = gdf.all_per_10k.min(), 50 # District of Columbia has 112/10k which skews the colorscale, but the next highest is 50
# Choose the continuous colorscale "YlOrBr" from https://matplotlib.org/stable/tutorials/colors/colormaps.html
colormap = "YlOrBr"
gdf = makeColorColumn(gdf,variable,vmin,vmax)

visframe = gdf.to_crs('epsg:2163')

fig, ax = plt.subplots(1, figsize=(18, 14))
# remove the axis box around the vis
ax.axis('off')

# add a title and annotation
ax.set_title('Homeless per 10k people\n2010-2017', fontdict={'fontsize': '42', 'fontweight' : '1'})

# Create colorbar legend
fig = ax.get_figure()
# add colorbar axes to the figure
# This will take some iterating to get it where you want it [l,b,w,h] right
# l:left, b:bottom, w:width, h:height; in normalized unit (0-1)
cbax = fig.add_axes([0.89, 0.21, 0.03, 0.31])   

cbax.set_title('# of Homeless\nper 10k individuals\n', fontdict={'fontsize': '15', 'fontweight' : '0'})

# add color scale
sm = plt.cm.ScalarMappable(cmap=colormap, \
                 norm=plt.Normalize(vmin=vmin, vmax=vmax))
# reformat tick labels on legend
sm._A = []
# comma_fmt = FuncFormatter(lambda x, p: format(x/100, '.0%'))
fig.colorbar(sm, cax=cbax)
tick_font_size = 16
cbax.tick_params(labelsize=tick_font_size)

# create map
# Note: we're going state by state here because of unusual coloring behavior when trying to plot the entire dataframe using the "value_determined_color" column
for row in visframe.itertuples():
    if row.STUSPS not in ['AK','HI']:
        vf = visframe[visframe.STUSPS==row.STUSPS]
        c = gdf[gdf.STUSPS==row.STUSPS][0:1].value_determined_color.item()
        vf.plot(color=c, linewidth=0.8, ax=ax, edgecolor='0.8')

# add Alaska
akax = fig.add_axes([0.1, 0.17, 0.2, 0.19])   
akax.axis('off')
# polygon to clip western islands
polygon = Polygon([(-170,50),(-170,72),(-140, 72),(-140,50)])
alaska_gdf = gdf[gdf.STUSPS=='AK']
alaska_gdf.clip(polygon).plot(color=gdf[gdf.STUSPS=='AK'].value_determined_color, linewidth=0.8,ax=akax, edgecolor='0.8')

# add Hawaii
hiax = fig.add_axes([.28, 0.20, 0.1, 0.1])   
hiax.axis('off')
# polygon to clip western islands
hipolygon = Polygon([(-160,0),(-160,90),(-120,90),(-120,0)])
hawaii_gdf = gdf[gdf.STUSPS=='HI']
hawaii_gdf.clip(hipolygon).plot(color=hawaii_gdf['value_determined_color'], linewidth=0.8,ax=hiax, edgecolor='0.8')
fig.savefig("../figures/homeless_rate_by_state_heatmap.png") 
plt.show()

# %% [markdown]
# ## Correlations
# - Housing Market Conditions
# - Economic Conditions (income)
# - Local Policy and Safety Net
# - Demographic of population
# - Climate

# %%
corr_matrix = df.corr(numeric_only=True)
# print(corr_matrix[corr_matrix["all_per_10k"] > 0.05]["all_per_10k"])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(corr_matrix[corr_matrix["all_per_10k"] > 0.05]["all_per_10k"])
# Out:
# pit_tot_shelt_pit_hud               0.237273
# pit_tot_unshelt_pit_hud             0.299069
# pit_tot_hless_pit_hud               0.310352
# pit_ind_shelt_pit_hud               0.256645
# pit_ind_unshelt_pit_hud             0.267569
# pit_ind_hless_pit_hud               0.308624
# pit_perfam_shelt_pit_hud            0.218516
# pit_perfam_unshelt_pit_hud          0.298748
# pit_perfam_hless_pit_hud            0.260499
# pit_ind_chronic_hless_pit_hud       0.303314
# pit_perfam_chronic_hless_pit_hud    0.331330
# pit_vet_hless_pit_hud               0.263696
# econ_urb_urbanicity                 0.168707
# coctag                              0.059976
# hou_pol_totalind_hud                0.311837
# hou_pol_totalday_hud                0.311966
# hou_pol_totalexit_hud               0.283241
# hou_pol_numret6mos_hud              0.247422
# hou_pol_numret12mos_hud             0.257451
# hou_pol_fedfundcoc                  0.194876
# hou_pol_fund_project                0.137394
# hou_pol_bed_es_hic_hud              0.200522
# hou_pol_bed_oph_hic_hud             0.068956
# hou_pol_bed_psh_hic_hud             0.246658
# hou_pol_bed_rrh_hic_hud             0.111830
# hou_pol_bed_sh_hic_hud              0.155872
# hou_pol_bed_th_hic_hud              0.223379
# hou_pol_perm_bed_hic_hud            0.243637
# hou_pol_temp_bed_hic_hud            0.225098
# dem_soc_asian_census                0.170229
# dem_soc_pacific_census              0.156846
# dem_soc_racetwo_census              0.090550
# dem_soc_hispanic_census             0.072070
# total_rent_inventory_acs5yr         0.105159
# dem_soc_ed_lesshs_acs5yr            0.171953
# dem_soc_singparent_acs5yr           0.141687
# econ_labor_incineq_acs5yr           0.253213
# econ_labor_pov_acs5yr               0.144860
# dem_soc_singadult_acs5yr            0.209375
# econ_sn_cashasst_acs5yr             0.168989
# hou_mkt_homeval_acs5yr              0.340273
# hou_mkt_medrent_acs5yr              0.233727
# hou_mkt_medrentgross_acs5yr         0.213784
# hou_mkt_ovrcrowd_acs5yr             0.312074
# hou_mkt_rentshare_acs5yr            0.391311
# hou_mkt_burden_own_acs5yr           0.286196
# hou_mkt_burden_sev_own_acs5yr       0.407907
# hou_mkt_burden_rent_acs5yr          0.224860
# hou_mkt_burden_sev_rent_acs5yr      0.269379
# econ_labor_unemp_rate_BLS           0.171109
# dem_pop_density_census              0.255144
# hou_mkt_density_census              0.265722
# hou_pol_hudunit_psh_hud             0.131570
# hou_mkt_pplunit_psh_hud             0.076383
# hou_pol_eli_psh_hud                 0.073809
# econ_sn_ssi_part_SSA                0.073879
# econ_sn_ssi_pay_SSA                 0.087759
# econ_sn_ssi_part_rate_SSA           0.200182
# hou_mkt_renter_count_evlab          0.092260
# dem_health_alcoholdeath_IMHE        0.363943
# dem_mort_lifeexp_IMHE               0.070753
# dem_health_excesdrink_chr           0.187763
# hou_pol_hlessconduct_total          0.197912
# hou_pol_hlessconduct_sleep          0.214405
# hou_pol_hlessconduct_loiter         0.100524
# hou_pol_hlessconduct_beg            0.159554
# cpi_2017                            0.105748
# env_wea_avgtemp_noaa                0.297431
# env_wea_precip_noaa                 0.153073
# pit_miss                            0.313018
# pit_shelt_pit_hud_share             0.636016
# pit_unshelt_pit_hud_share           0.848312
# pit_hless_pit_hud_share             1.000000
# dem_pop_adult_census_share          0.199585
# dem_pop_male_census_share           0.105295
# dem_pop_mig_census_share            0.111144
# dem_soc_asian_census_share          0.180080
# dem_soc_hispanic_census_share       0.197902
# dem_soc_pacific_census_share        0.164399
# dem_soc_racetwo_census_share        0.189454
# dem_soc_other_census_share          0.133574
# dem_health_excesdrink_chr_2017      0.155432
# dem_health_alcdeath_IMHE_2015       0.340880
# dem_soc_ed_lesshs_acs5yr_2012       0.160832
# dem_soc_ed_lesshs_acs5yr_2017       0.166166
# dem_soc_singparent_acs5yr_2012      0.164002
# dem_soc_singparent_acs5yr_2017      0.123942
# dem_soc_singadult_acs5yr_2012       0.226673
# dem_soc_singadult_acs5yr_2017       0.212678
# econ_labor_incineq_acs5yr_2012      0.263763
# econ_labor_incineq_acs5yr_2017      0.289541
# econ_labor_incineq_acs5yr_diff      0.072832
# econ_labor_topskill_acs5yr_diff     0.119676
# econ_labor_unskill_acs5yr_diff      0.083247
# econ_labor_pov_pop_census_share     0.171548
# econ_sn_cashasst_acs5yr_2012        0.166408
# econ_sn_cashasst_acs5yr_2017        0.158131
# hou_mkt_rentshare_acs5yr_2012       0.398883
# hou_mkt_rentshare_acs5yr_2017       0.391802
# hou_mkt_ovrcrowd_acs5yr_2012        0.288616
# hou_mkt_ovrcrowd_acs5yr_2017        0.316307
# hou_mkt_ovrcrowd_acs5yr_diff        0.096786
# hou_mkt_homeage1940_acs5yr_diff     0.242931
# hou_mkt_homeval_acs5yr_2012         0.339177
# hou_mkt_homeval_acs5yr_2017         0.326502
# hou_mkt_medrent_acs5yr_2012         0.258433
# hou_mkt_medrent_acs5yr_2017         0.256907
# hou_mkt_medrent_acs5yr_diff         0.163516
# hou_mkt_burden_own_acs5yr_2012      0.240682
# hou_mkt_burden_own_acs5yr_2017      0.261421
# hou_mkt_burden_sev_own_acs_2012     0.395400
# hou_mkt_burden_sev_own_acs_2017     0.356333
# hou_mkt_burden_rent_acs5yr_2012     0.235196
# hou_mkt_burden_rent_acs5yr_2017     0.202469
# hou_mkt_burden_sev_rent_acs_2012    0.242515
# hou_mkt_burden_sev_rent_acs_2017    0.286337
# hou_mkt_burden_sev_rent_acs_diff    0.074583
# hou_pol_hudunit_psh_hud_share       0.191271
# urban_cat                           0.134512
# evict_file_flag                     0.114731
# evict_flag                          0.089782
# hou_mkt_density_dummy               0.058596
# hou_mkt_homeval_xt                  0.349501
# hou_mkt_burden_own_xt               0.356745
# hou_mkt_burden_sev_own_xt           0.407992
# hou_mkt_burden_rent_xt              0.316530
# hou_mkt_burden_sev_rent_xt          0.273530
# hou_mkt_medrent_xt                  0.248020
# hou_mkt_rentshare_xt                0.385357
# hou_mkt_ovrcrowd_xt                 0.318022
# econ_labor_incineq_xt               0.256143
# econ_sn_cashasst_xt                 0.171512
# dem_soc_ed_lesshs_xt                0.179415
# dem_soc_singadult_xt                0.209036
# dem_soc_singparent_xt               0.139210
# ln_hou_mkt_homeval_xt               0.328343
# ln_hou_mkt_medrent_xt               0.260144
# d_hou_mkt_burden_sev_rent_xt        0.111996
# d_hou_mkt_burden_rent_xt            0.054751
# d_hou_mkt_medrent_xt                0.232415
# d_fhfa_hpi_2009                     0.415070
# d_hou_mkt_homeage1940_xt            0.196930
# d_hou_mkt_rentvacancy_xt            0.069204
# d_hou_mkt_ovrcrowd_xt               0.114288
# d_hou_mkt_pctoverhouse_psh_hud      0.116096
# d_hou_mkt_evict_rate                0.071432
# d_hou_pol_fedfundcoc                0.140975
# d_econ_labor_medinc_census          0.267178
# d_econ_labor_incineq_xt             0.079857
# d_dem_soc_hispanic_census_share     0.140431
# d_dem_soc_asian_census_share        0.062404
# d_dem_pop_child_census_share        0.106983
# d_dem_pop_senior_census_share       0.138571
# d_dem_pop_female_census_share       0.249203
# d_dem_health_cost_dart              0.233583
# d_env_wea_avgtemp_summer_noaa       0.183008
# d_env_wea_precip_noaa               0.431767
# census_region                       0.277349
# census_division                     0.281149
# sub_west_coast                      0.354410
# sub_low_rent_vacancy                0.113729
# sub_high_cost_rent75                0.087744
# sub_high_cost_homeval75             0.128134
# sub_high_rent_share75               0.154447
# tight_high_cost_rental_mkt          0.160487
# sub_tight_high_cost_rent            0.114861
# sub_west_coast_all_urb              0.238708
# sub_west_census                     0.327139
# major_city                          0.157826
# shelt_per_10k                       0.636016
# unshelt_per_10k                     0.848312
# all_per_10k                         1.000000
# urbanicity                          0.134512
# Name: all_per_10k, dtype: float64

# %%
sns.violinplot(data=df, x="urbanicity", y="all_per_10k")
# Out:
# <Axes: xlabel='urbanicity', ylabel='all_per_10k'>

# %% [markdown]
# ### Housing Market Conditions

# %%
# hou_mkt_rentshare_acs5yr - share of renter-occupied housing units to all occupied housing units
sns.scatterplot(data=df,x="hou_mkt_rentshare_acs5yr",y="all_per_10k", hue="urbanicity")
plt.xlabel("Share of renter-occupied to all occupied housing units")
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and Renter-Share")
plt.show()

# %%
# hou_mkt_medrentgross_acs5yr - median gross rent for renter-occupied housing units
sns.scatterplot(data=df,x="hou_mkt_medrentgross_acs5yr", y="all_per_10k", hue="urbanicity")
plt.xlabel("Median Gross Rent for Renter-Occupied Units ($)")
plt.ylabel("People homeless per 10,000")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Median Rent")
plt.show()

# %%
# fhfa_hpi_2009 - 2009 base year house price index (HPI), from FHFA
sns.scatterplot(data=df,x="fhfa_hpi_2009",y="all_per_10k", hue="urbanicity")
plt.xlabel("2009 House Price Index")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and House Price Index")
plt.show()

# %%
# hou_mkt_evict_rate - share of renter evictions
sns.scatterplot(data=df,x="hou_mkt_evict_rate",y="all_per_10k", hue="urbanicity", alpha=0.8)
plt.xlabel("Share of Renter-Occupied houses with evictions (%)")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and Evictions")
plt.show()

# %%
# d_fhfa_hpi_2009 - 4-year change in fhfa_hpi_2009 values (2017 and 2013)
sns.scatterplot(data=df,x="d_fhfa_hpi_2009",y="all_per_10k", alpha=0.8, hue="urbanicity")
plt.xlabel("4-year change in Housing Price Index (HPI)")
plt.ylabel("People homeless per 10,000")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Change in Housing Price Index")
fig.savefig("hmless_and_hpi.png") 
plt.show()

# %% [markdown]
# ### Economic Conditions

# %%
# econ_labor_unemp_rate_BLS - unemployment rate
sns.scatterplot(data=df,x="econ_labor_unemp_rate_BLS", y="all_per_10k", hue="urbanicity")
plt.xlabel("Unemployment Rate")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and Unemployemnt Rate")
plt.show()

# %%
# econ_labor_incineq_acs5yr - gini coefficent between households
sns.scatterplot(data=df,x="econ_labor_incineq_acs5yr",y="all_per_10k", hue="urbanicity", alpha=0.8)
plt.xlabel("Income Inequality (measured by Gini index)")
plt.ylabel("People homeless per 10,000")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Inequality")
fig.savefig("hmless_and_inequality.png") 
plt.show()

# %% [markdown]
# ### Local Policy / Safety Net

# %%
# hou_pol_hlessconduct_total - total number of prohibited conduct laws
sns.scatterplot(data=df,x="hou_pol_hlessconduct_total",y="all_per_10k", hue="urbanicity")
plt.xlabel("Number of Prohibited Conduct Laws")
plt.ylabel("People homeless per 10,000")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Prohibited Conduct Laws")
plt.show()

# %%
# econ_sn_ssdi_part_rate_SSA - share of population receiving disability benefits
sns.scatterplot(data=df,x="econ_sn_ssdi_part_rate_SSA",y="all_per_10k", hue="urbanicity")
plt.xlabel("Share of population receiving disability benefits (%)")
plt.ylabel("People homeless per 10,000")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Disability Benefits")
plt.show()

# %% [markdown]
# ### Demographics

# %%
# dem_pop_density_census - population density
sns.scatterplot(data=df,x="dem_pop_density_census", y="all_per_10k", hue="urbanicity")
plt.xscale("log")
plt.xlabel("Population Density (ppl per sq mi)")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and Population Density")
plt.show()

# %%
# dem_health_alcoholdeath_IMHE - 2014 mortality rate of alcohol use disorders, per 100,000 population, from IMHE
sns.scatterplot(data=df,x="dem_health_alcoholdeath_IMHE", y="all_per_10k")
plt.xlabel("Alcohol Use Disorder Mortality Rate (%)")
plt.ylabel("People homeless per 10,000")
# plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Alcohol Use Disorder Mortality Rate")
fig.savefig("hmless_and_aud.png") 
plt.show()

# %%
# dem_soc_singadult_acs5yr - proportion of 1-person households to all households
sns.scatterplot(data=df,x="dem_soc_singadult_acs5yr", y="all_per_10k", hue="urbanicity")
plt.xlabel("Proportion of 1-person households to all households")
plt.ylabel("People homeless per 10,000")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.title("Homeless Share and Share of 1-person households")
plt.show()

# %%
# hou_mkt_density_census - housing density
sns.scatterplot(data=df,x="hou_mkt_density_census", y="all_per_10k", hue="urbanicity")
plt.xscale("log")
plt.legend(labels=["Rural", "Suburban", "Urban"])
plt.xlabel("Housing Density (houses per sq mi)")
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and Housing Density")
plt.show()

# %% [markdown]
# ### Climate

# %%
# env_wea_avgtemp_noaa - average January temperature
sns.scatterplot(data=df,x="env_wea_avgtemp_noaa", y="all_per_10k", alpha=0.5)
plt.xlabel("Average January Temp")
plt.ylabel("People homeless per 10,000")
plt.title("Homeless Share and Average January Temp")
plt.show()
